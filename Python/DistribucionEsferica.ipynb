# %%
# %pylab inline
from mpl_toolkits.mplot3d import Axes3D
n=1000
x=[]
y=[]
z=[]
r=random.random(n)
th=2*pi*random.random(n)
ph=pi*random.random(n)
for i in range(n):
    x.append(r[i]*sin(th[i])*sin(ph[i]))
    y.append(r[i]*cos(th[i])*sin(ph[i]))
    z.append(r[i]*cos(ph[i]))
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.scatter(x, y, z)
# Out:
# Populating the interactive namespace from numpy and matplotlib
